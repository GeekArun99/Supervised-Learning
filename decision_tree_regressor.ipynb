# %%
#Decision tree regressor
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_diabetes

# %%
df = load_diabetes(as_frame=True).frame

# %%
df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  target
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
X= df.drop("target", axis =1)
y=df["target"]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X,y, test_size=0.3, random_state=42
)

# %%
from sklearn.tree import DecisionTreeRegressor, plot_tree
model = DecisionTreeRegressor(max_depth=7, min_samples_leaf=15)
model.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor(max_depth=7, min_samples_leaf=15)

# %%
from sklearn.metrics import r2_score, mean_squared_error

y_pred_train = model.predict(X_train)
y_pred_test = model.predict(X_test)

print("MSE train :", mean_squared_error(y_train,y_pred_train))
print("MSE train :", mean_squared_error(y_test,y_pred_test))

print("r2 train :", r2_score(y_train,y_pred_train))
print("r2 train :", r2_score(y_test,y_pred_test))
# Out:
# MSE train : 2555.2382846027754
# MSE train : 3257.0641380105967
# r2 train : 0.5843979907414765
# r2 train : 0.396650898452531

# %%
plt.figure(figsize=(18,10))

plot_tree(
    model,
    feature_names =X.columns,
    filled=True
)

plt.show()
